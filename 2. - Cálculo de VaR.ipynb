# %%
import pandas as pd
import numpy as np

# %%
weights = {
    'AMXB': 0.08,
    'CEMEX': 0.11,
    'GAPB': 0.12,
    'LACOMER': 0.09,
    'PENOLES': 0.21,
    'BANREGIO': 0.14,
    'VOLARIS': 0.17,
    'FIBRAPL': 0.08
}

# %%
portfolio_value = 350_000_000  # 350 millones de pesos

# %%
file_path = "Data.xlsx"

returns = []

for asset, w in weights.items():
    
    df = pd.read_excel(
        file_path,
        sheet_name=asset,
        header=2
    )
    
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values('Date')
    
    df['Return'] = df['Price'].pct_change().dropna()
    
    df = df[['Date', 'Return']].dropna()
    df = df.rename(columns={'Return': asset})
    
    returns.append(df.set_index('Date'))

# %%
returns_df = pd.concat(returns, axis=1).dropna()
returns_df.head()
# Out:
#                 AMXB     CEMEX      GAPB   LACOMER   PENOLES  BANREGIO  \
# Date
# 2024-01-29  0.001293  0.009894  0.012080  0.001970  0.072147 -0.005445
# 2024-01-30  0.005165  0.006298 -0.014657 -0.001474 -0.026984  0.016298
# 2024-01-31 -0.001285 -0.005563 -0.013439 -0.005415 -0.025321 -0.010897
# 2024-02-01 -0.003859  0.008392  0.005673  0.004454 -0.006406  0.001315
# 2024-02-02  0.001291  0.020111  0.036627 -0.001232 -0.035573  0.012253
#
#              VOLARIS   FIBRAPL
# Date
# 2024-01-29  0.025018 -0.019874
# 2024-01-30 -0.032078 -0.013410
# 2024-01-31 -0.008646  0.025000
# 2024-02-01  0.000727 -0.011138
# 2024-02-02  0.006536  0.012546

# %%
weights_array = np.array(list(weights.values()))
returns_df['Portfolio_Return'] = np.dot(returns_df, weights_array)

# %%
VaR_99 = -np.percentile(returns_df['Portfolio_Return'], 1)
VaR_99 * 100, VaR_99 * portfolio_value
# Out:
# (np.float64(2.8611433660175476), np.float64(10014001.781061416))

# %%
VaR_95 = -np.percentile(returns_df['Portfolio_Return'], 5)
VaR_95 * 100, VaR_95 * portfolio_value
# Out:
# (np.float64(1.9799543673876623), np.float64(6929840.285856819))
